# %%
import pandas as pd
df=pd.read_excel('반도체_공정설계_3차과제_raw_data.xlsx',skiprows=2,usecols='B:N')
df
# Out:
#      Stepseq Step_Description Type  Tkin_time   Lot ID  Wafer ID  Lot&Wafer  \
# 0   AB000840     Silicide 두께    계측      44538  KZABC.1         1  KZABC.1_1
# 1   AB000840     Silicide 두께    계측      44538  KZABC.1         1  KZABC.1_1
# 2   AB000840     Silicide 두께    계측      44538  KZABC.1         1  KZABC.1_1
# 3   AB000840     Silicide 두께    계측      44538  KZABC.1         1  KZABC.1_1
# 4   AB000840     Silicide 두께    계측      44538  KZABC.1         1  KZABC.1_1
# ..       ...              ...  ...        ...      ...       ...        ...
# 86  AB000840     Silicide 두께    계측      44532  KH379.1         9  KH379.1_9
# 87  AB000840     Silicide 두께    계측      44532  KH379.1         9  KH379.1_9
# 88  AB000840     Silicide 두께    계측      44532  KH379.1         9  KH379.1_9
# 89  AB000840     Silicide 두께    계측      44532  KH379.1         9  KH379.1_9
# 90  AB000840     Silicide 두께    계측      44532  KH379.1         9  KH379.1_9
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size']=15
matplotlib.rcParams['axes.unicode_minus']=False

# %%
plt.figure(figsize=(30,5))
plt.plot(df['Lot_W_C'],df['Value(Å)'],label='Value')
plt.plot(df['Lot_W_C'],df['Spec high'],label='Spec High')
plt.plot(df['Lot_W_C'],df['Target'],label='Target')
plt.plot(df['Lot_W_C'],df['Spec low'],label='Spec Low')
plt.xticks(df['Lot_W_C'], rotation=90)
plt.ylim(180,260)
plt.yticks([180,200,220,240,260])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel('반도체_공정설계_3차과제_raw_data.xlsx',skiprows=2,usecols='Q:AC')
df
# Out:
#    Stepseq.1 Step_Description.1 Type.1  Tkin_time.1 Lot ID.1  Wafer ID.1  \
# 0   AB001020  Contact Etch 후 CD     CD        44538  KZABC.1           1
# 1   AB001020  Contact Etch 후 CD     CD        44538  KZABC.1           1
# 2   AB001020  Contact Etch 후 CD     CD        44538  KZABC.1           1
# 3   AB001020  Contact Etch 후 CD     CD        44538  KZABC.1           1
# 4   AB001020  Contact Etch 후 CD     CD        44538  KZABC.1           1
# ..       ...                ...    ...          ...      ...         ...
# 86  AB001020  Contact Etch 후 CD     CD        44550  KH379.1           9
# 87  AB001020  Contact Etch 후 CD     CD        44550  KH379.1           9
# 88  AB001020  Contact Etch 후 CD     CD        44550  KH379.1           9
# 89  AB001020  Contact Etch 후 CD     CD        44550  KH379.1           9
# 90  AB001020  Contact Etch 후 CD     CD        44550  KH379.1           9
#
#    Lot&Wafer.1 CHIP_X_Y.1      Lot_W_C.1  Value(um)  Spec high.1  Target.1  \
# ...

# %%
plt.figure(figsize=(30,5))
plt.plot(df['Lot_W_C.1'],df['Value(um)'],label='Value')
plt.plot(df['Lot_W_C.1'],df['Spec high.1'],label='Spec High')
plt.plot(df['Lot_W_C.1'],df['Target.1'],label='Target')
plt.plot(df['Lot_W_C.1'],df['Spec low.1'],label='Spec Low')
plt.xticks(df['Lot_W_C.1'], rotation=90)
plt.yticks(np.arange(0.034, 0.05, 0.002))
plt.show()
